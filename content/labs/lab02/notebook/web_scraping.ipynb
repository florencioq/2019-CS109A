# %%
## RUN THIS CELL TO GET THE RIGHT FORMATTING 
from IPython.core.display import HTML
def css_styling():
    styles = open("../../../styles/cs109.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #ffcccc;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
# div.theme {
# 	background-color: #DDDDDD;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
#     padding-top: 5px;
#     padding-bottom: 5px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
# header {
#    padding-top: 35px;
#     padding-bottom: 35px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# </style>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# import seaborn.apionly as sns
import time

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.worldometers.info/"
response = requests.get(url) # you can use any URL that you wish

# %%
soup = BeautifulSoup(response.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]--><!--[if IE 9]> <html lang="en" class="ie9"> <![endif]--><!--[if !IE]><!--> <html lang="en"> <!--<![endif]--> <head> <meta charset="utf-8"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=device-width, initial-scale=1" name="viewport"/> <title>Worldometer - real time world statistics</title><meta content="Live world statistics on population, government and economics, society and media, environment, food, water, energy and health. Interesting statistics with world population clock, forest loss this year, carbon dioxide co2 emission, world hunger data, energy consumed, and a lot more" name="description"/><meta content="Worldometer - real time world statistics" property="og:title"><meta content="website" property="og:type"><meta content="http://www.worldometers.info/" property="og:url"><meta content="http://www.worldometers.info/img/worldometers-fb.jpg" property="og:image"><meta content="Worldometer" property="og:site_name"/><meta content="1810087514" property="fb:admins"/><meta content="Live world statistics on population, government and economics, society and media, environment, food, water, energy and health." property="og:description"/><script type="application/ld+json">{ "@context" : "http://schema.org", "@type" : "Organization", "name" : "Worldometer", "url" : "http://www.worldometers.info", "logo": "http://www.worldometers.info/img/logo-schema.gif", "sameAs" : [ "https://www.facebook.com/Worldometers.info", "https://twitter.com/Worldometers", "https://plus.google.com/+worldometers"]
# }</script><link href="/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link href="/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/><link href="/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/favicon/manifest.json" rel="manifest"/><meta content="#ffffff" name="msapplication-TileColor"/><meta content="/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/><meta content="#ffffff" name="theme-color"/><meta content="http://www.worldometers.info/img/worldometers-fb.jpg" property="og:image"> <link href="/css/bootstrap.min.css" rel="stylesheet"/><link href="/wm16.css" rel="stylesheet"/> <!--[if lt IE 9]> <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script> <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script> <![endif]--><script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script><script type="text/javascript"> var rts_configuration =
# {
# RTS_key: 'worldometers',
# RTS_keylen: 2,
# format_defaults : {
# decimalSeparator: '.',
# thousandSeparator: ','
# }
# }</script><script src="https://www.realtimestatistics.net/rts/RTSp.js" type="text/javascript"></script><script src="/js/counters.js" type="text/javascript"></script><link href="/css/accordion16.css" media="screen" rel="stylesheet" type="text/css"/><script type="text/javascript">$(document).ready(function () { $('.collapse') .on('shown.bs.collapse', function() { $(this) .parent() .find(".inactive-header") .removeClass("inactive-header") .addClass("active-header"); }) .on('hidden.bs.collapse', function() { $(this) .parent() .find(".active-header") .removeClass("active-header") .addClass("inactive-header"); }); });</script><link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/> <script src="/js/bootstrap.min.js"></script> <script src="/js/ie10-viewport-bug-workaround.js"></script></meta></meta></meta></meta></meta></head><body><script> (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){ (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o), m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m) })(window,document,'script','//www.google-analytics.com/analytics.js','ga'); ga('create', 'UA-1438574-2', 'auto'); ga('send', 'pageview');</script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1438574-30"></script><script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'UA-1438574-30');</script><link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.css" rel="stylesheet" type="text/css"><script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.js"></script><script>window.addEventListener("load", function(){
# window.cookieconsent.initialise({ "palette": { "popup": { "background": "#efefef", "text": "#404040" }, "button": { "background": "#8ec760", "text": "#ffffff" } }, "theme": "classic", "content": { "href": "http://www.worldometers.info/policy/" }
# })});</script><style type="text/css"> .style1 { color: #666666 }</style><div class="navbar navbar-default"> <div class="container"> <div class="navbar-header"> <div class="logo"><a class="navbar-brand" href="/"><img border="0" src="/img/worldometers-logo.gif" title="Worldometer"/></a></div> <button class="navbar-toggle" data-target="#navbar-main" data-toggle="collapse" type="button"> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span> </button> </div> <div class="navbar-collapse collapse" id="navbar-main"> <ul class="nav navbar-nav"> <li><a href="/coronavirus/"><span style="color:#FF9900; font-weight:bold">Coronavirus</span></a></li> <li><a href="/population/">Population</a></li> </ul> </div> </div></div><div class="container"><div class="row"><div style="text-align:left; margin-bottom:10px"><script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-slot="3287840995" style="display:inline-block;width:970px;height:90px"></ins><script> (adsbygoogle = window.adsbygoogle || []).push({});</script></div></div><div class="row"> <div class="col-md-2 hidden-sm hidden-xs col-wm-left-ad"> <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-slot="9468680730" style="display:inline-block;width:160px;height:600px"></ins><script>(adsbygoogle = window.adsbygoogle || []).push({});</script></div><div class="col-md-6"> <div class="content-home"><div class="linkunderline" style="padding:20px; margin-bottom:20px; margin-top:20px; font-size:16px"><a href="/coronavirus/"><strong>Coronavirus Updates</strong></a></div><div class="counterdiv"><div class="counter-title-top">World Population</div><div class="counter-group" id="c1"><div class="counter-heading inactive-header" data-parent="#c1" data-target="#current_population" data-toggle="collapse"> <span class="counter-number"><span class="rts-counter" rel="current_population">retrieving data...</span></span><span class="counter-item"><a href="/world-population/">Current World Population</a></span></div><div class="collapse counter-body-wrap" id="current_population"><div class="counter-body"> <strong>World Population: </strong> <ul> <li>has reached 7 billion on October 31, 2011.</li> <li>is projected to reach 8 billion in 2023, 9 billion in 2037, and 10 billion people in the year 2055.</li> <li>has doubled in 40 years from 1959 (3 billion) to 1999 (6 billion).</li> <li>is currently (2020) growing at a rate of around 1.05 % per year, adding 81 million people per year to the total.</li> <li>growth rate reached its peak in the late 1960s, when it was at 2.09%.</li> <li>growth rate is currently declining and is projected to continue to decline in the coming years (reaching below 0.50% by 2050, and 0.03% in 2100) . </li> <li>a tremendous change occurred with the industrial revolution: whereas it had taken all of human history up to the year 1800 for world population to reach 1 billion, the second billion was achieved in only 130 years (1930), the third billion in 30 years (1960), the fourth billion in 15 years (1974), the fifth billion in 13 years (1987), the sixth billion in 12 years (1999) and the seventh billion in 12 years (2011). During the 20th century alone, the population in the world has grown from 1.65 billion to 6 billion.</li> </ul> <p><strong>Sources for the world population counter:</strong></p> <ul> <li><a href="https://esa.un.org/unpd/wpp/" target="_blank">World Population Prospect: the 2019 Revision</a> - United Nations, Department of Economic and Social Affairs, Population Division (June 2019)</li> <li><a href="http://www.census.gov/population/international/" target="_blank">International Programs Center at the U.S. Census Bureau, Population Division</a></li> </ul> <p><strong>For more detailed information: </strong></p> <ul> <li><a hr ...
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
# _qevents.push({
# qacct:"p-Pd9JxUkvV0m7q"
# });</script><noscript><div style="display:none;"><img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-Pd9JxUkvV0m7q.gif" width="1"/></div></noscript></link></body></html>

# %%
for link in soup.find_all('a'): # we could optionally pass the href=True flag .find_all('a', href=True)
    print(link.get('href'))
# Out:
# /
# /coronavirus/
# /population/
# /coronavirus/
# /world-population/
# https://esa.un.org/unpd/wpp/
# http://www.census.gov/population/international/
# /world-population/
# /world-population/
# javascript:void(0)
# http://www.who.int/gho/publications/world_health_statistics/2017/en/
# https://www.imf.org/external/ns/cs.aspx?id=28
# http://data.worldbank.org/data-catalog/world-development-indicators
# javascript:void(0)
# http://hdr.undp.org/en/
# http://www.uis.unesco.org/Education/Pages/global-education-digest.aspx
# http://web.worldbank.org/WBSITE/EXTERNAL/TOPICS/EXTEDUCATION/EXTDATASTATISTICS/EXTEDSTATS/0,,contentMDK:21878970%7EmenuPK:5313042%7EpagePK:64168445%7EpiPK:64168309%7EtheSitePK:3232764,00.html
# /education/
# javascript:void(0)
# http://www.sipri.org/research/armaments/milex
# /military/
# javascript:void(0)
# http://oica.net/category/production-statistics/
# http://www.gbm.scotiabank.com/English/bns_econ/bns_auto.pdf
# http://www.ihs.com/products/automotive/light-vehicle-forecasts/light-vehicle-production.aspx
# /cars/
# javascript:void(0)
# http://www.worldwatch.org/node/5462
# /bicycles/
# javascript:void(0)
# https://www.gartner.com/newsroom/id/3844572
# http://www.gartner.com/technology/home.jsp
# http://www.idc.com/tracker/showproductinfo.jsp?prod_id=1
# http://www.idc.com/
# /computers/
# javascript:void(0)
# http://www.bowker.com/en-US/
# http://www.uis.unesco.org/Pages/default.aspx
# /books/
# javascript:void(0)
# http://www.wan-ifra.org/microsites/world-press-trends
# http://www.wan-ifra.org/
# /newspapers/
# javascript:void(0)
# http://www.displaysearch.com/cps/rde/xchg/displaysearch/hs.xsl/reports_tvs.asp
# javascript:void(0)
# http://www.gartner.com/technology/home.jsp
# http://www.idc.com/prodserv/idc_telnet.jsp
# javascript:void(0)
# http://www.gartner.com
# http://www.dfcint.com/
# http://www.npd.com/corpServlet?nextpage=entertainment-categories_s.html
# http://data.worldbank.org/data-catalog/world-development-indicators
# http://www.itu.int/ITU-D/ict/publications/idi/
# http://www.comscore.com/
# http://www.gfk.com/
# http://www.internetlivestats.com/internet-users/
# javascript:void(0)
# http://www.radicati.com/
# javascript:void(0)
# http://technorati.com/state-of-the-blogosphere/
# http://en.wordpress.com/stats/
# /blogs/
# javascript:void(0)
# http://www.internetlivestats.com/twitter-statistics/
# javascript:void(0)
# http://www.comscore.com/
# http://www.google.com/about/company/
# http://www.internetlivestats.com/google-search-statistics/
# javascript:void(0)
# http://www.fao.org/forestry/fra/en/
# javascript:void(0)
# http://www.fao.org/docrep/u8480e/U8480E0D.HTM
# /co2-emissions/
# javascript:void(0)
# https://www.iea.org/statistics/
# http://cdiac.ornl.gov/
# http://www.eia.gov/
# /co2-emissions/
# javascript:void(0)
# http://www.unccd.int/
# javascript:void(0)
# http://www.epa.gov/tri/
# http://www.unep.org/
# http://www.epa.gov/
# /view/toxchem/
# http://www.fao.org/publications/sofi/en/
# /undernourishment/
# http://www.who.int/mediacentre/factsheets/fs311/en/
# /weight-loss/
# http://www.who.int/mediacentre/factsheets/fs311/en/
# /obesity/
# javascript:void(0)
# http://www.wfp.org/hunger/stats
# http://www.who.int/whr/en/index.html
# http://www.unicef.org/sowc/index.html
# javascript:void(0)
# http://www.unccd.int/
# /obesity/
# javascript:void(0)
# http://content.healthaffairs.org/content/28/5/w822.short
# http://www.rti.org/
# http://www.ahrq.gov/
# http://www.cdc.gov/
# http://www.marketresearch.com/product/display.asp?productid=6314539
# http://www.americashealthrankings.org/
# /weight-loss/
# javascript:void(0)
# http://www.worldwatercouncil.org/en
# /water/
# javascript:void(0)
# http://www.who.int/mediacentre/factsheets/fs391/en/
# http://www.who.int/topics/water/en/
# http://www.who.int/water_sanitation_health/publications/jmp-2017/en/
# http://www.who.int/topics/water/en/
# http://www.who.int/water_sanitation_health/diseases-risks/diseases/diseasefact/en/
# /water/access-to-safe-water/
# https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy/downloads.html
# http://en.wikipedia.org/wiki/World_energy_consumption
# /energy/
# http://www.iea.org/stats/index.asp
# javascript:void(0)
# http://books.google.com/books/about/Energy.html?id=lm1WAAAACAAJ
# http://en.wikipedia.org/wiki/Solar_energy
# http://www.eia.gov/cfapps/ipdbproject/IEDIndex3.cfm?tid=5&pid=57&aid=6
# /oil/
# http://www.eia.gov/cfapps/ipdbproject/IEDIndex3.cfm?tid=5&pid=57&aid=6
# /oil/
# http://www.eia.gov/cfapps/ipdbproject/IEDIndex3.cfm?tid=5&pid=57&aid=6
# http://www.eia.gov/cfapps/ipdbproject/IEDIndex3.cfm?tid=5&pid=57&aid=6
# /gas/
# /coal/
# javascript:void(0)
# http://www.who.int/healthinfo/global_burden_disease/en/
# javascript:void(0)
# https://www.cdc.gov/media/releases/2017/p1213-flu-death-estimate.html
# https://www.who.int/mediacentre/news/statements/2017/flu/en/
# javascript:void(0)
# http://www.unicef.org/childsurvival/index_newsline.html
# http://www.childinfo.org/mortality.html
# javascript:void(0)
# http://www.who.int/reproductivehealth/en/
# http://www.sogc.org/jogc/abstracts/full/200912_WomensHealth_1.pdf
# /abortions/
# javascript:void(0)
# http://www.who.int/features/qa/12/en/index.html
# http://www.thelancet.com/journals/lancet/article/PIIS0140-6736%2810%2960518-1/fulltext#
# http://www.who.int/hiv/data/en/
# http://www.avert.org/worldstats.htm
# /aids/
# javascript:void(0)
# http://www.unaids.org/en/dataanalysis/
# /aids/
# javascript:void(0)
# http://www.who.int/cancer/en/
# /cancer/
# javascript:void(0)
# http://www.who.int/features/factfiles/malaria/en/index.html
# javascript:void(0)
# http://www.who.int/tobacco/en/atlas8.pdf
# javascript:void(0)
# http://www.who.int/gho/tobacco/en/index.html
# javascript:void(0)
# http://www.who.int/gho/alcohol/en/index.html
# /alcohol/
# javascript:void(0)
# http://www.who.int/mental_health/prevention/suicide/suicideprevent/en/index.html
# javascript:void(0)
# http://www.pbs.org/wgbh/pages/frontline/shows/drugs/business/
# /drugs/
# javascript:void(0)
# http://www.who.int/mediacentre/events/meetings/2011/road_safety/en/index.html
# /
# /about/
# /faq/
# /languages/
# /contact/
# /newsletter-subscribe/
# https://twitter.com/Worldometers
# https://www.facebook.com/Worldometers.info
# /disclaimer/

# %%
soup.header

# %%
soup.title
# Out:
# <title>Worldometer - real time world statistics</title>

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]--><!--[if IE 9]> <html lang="en" class="ie9"> <![endif]--><!--[if !IE]><!--> <html lang="en"> <!--<![endif]--> <head> <meta charset="utf-8"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=device-width, initial-scale=1" name="viewport"/> <title>Worldometer - real time world statistics</title><meta content="Live world statistics on population, government and economics, society and media, environment, food, water, energy and health. Interesting statistics with world population clock, forest loss this year, carbon dioxide co2 emission, world hunger data, energy consumed, and a lot more" name="description"/><meta content="Worldometer - real time world statistics" property="og:title"><meta content="website" property="og:type"><meta content="http://www.worldometers.info/" property="og:url"><meta content="http://www.worldometers.info/img/worldometers-fb.jpg" property="og:image"><meta content="Worldometer" property="og:site_name"/><meta content="1810087514" property="fb:admins"/><meta content="Live world statistics on population, government and economics, society and media, environment, food, water, energy and health." property="og:description"/><script type="application/ld+json">{ "@context" : "http://schema.org", "@type" : "Organization", "name" : "Worldometer", "url" : "http://www.worldometers.info", "logo": "http://www.worldometers.info/img/logo-schema.gif", "sameAs" : [ "https://www.facebook.com/Worldometers.info", "https://twitter.com/Worldometers", "https://plus.google.com/+worldometers"]
# }</script><link href="/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link href="/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/><link href="/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/favicon/manifest.json" rel="manifest"/><meta content="#ffffff" name="msapplication-TileColor"/><meta content="/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/><meta content="#ffffff" name="theme-color"/><meta content="http://www.worldometers.info/img/worldometers-fb.jpg" property="og:image"> <link href="/css/bootstrap.min.css" rel="stylesheet"/><link href="/wm16.css" rel="stylesheet"/> <!--[if lt IE 9]> <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script> <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script> <![endif]--><script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script><script type="text/javascript"> var rts_configuration =
# {
# RTS_key: 'worldometers',
# RTS_keylen: 2,
# format_defaults : {
# decimalSeparator: '.',
# thousandSeparator: ','
# }
# }</script><script src="https://www.realtimestatistics.net/rts/RTSp.js" type="text/javascript"></script><script src="/js/counters.js" type="text/javascript"></script><link href="/css/accordion16.css" media="screen" rel="stylesheet" type="text/css"/><script type="text/javascript">$(document).ready(function () { $('.collapse') .on('shown.bs.collapse', function() { $(this) .parent() .find(".inactive-header") .removeClass("inactive-header") .addClass("active-header"); }) .on('hidden.bs.collapse', function() { $(this) .parent() .find(".active-header") .removeClass("active-header") .addClass("inactive-header"); }); });</script><link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/> <script src="/js/bootstrap.min.js"></script> <script src="/js/ie10-viewport-bug-workaround.js"></script></meta></meta></meta></meta></meta></head><body><script> (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){ (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o), m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m) })(window,document,'script','//www.google-analytics.com/analytics.js','ga'); ga('create', 'UA-1438574-2', 'auto'); ga('send', 'pageview');</script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1438574-30"></script><script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'UA-1438574-30');</script><link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.css" rel="stylesheet" type="text/css"><script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.js"></script><script>window.addEventListener("load", function(){
# window.cookieconsent.initialise({ "palette": { "popup": { "background": "#efefef", "text": "#404040" }, "button": { "background": "#8ec760", "text": "#ffffff" } }, "theme": "classic", "content": { "href": "http://www.worldometers.info/policy/" }
# })});</script><style type="text/css"> .style1 { color: #666666 }</style><div class="navbar navbar-default"> <div class="container"> <div class="navbar-header"> <div class="logo"><a class="navbar-brand" href="/"><img border="0" src="/img/worldometers-logo.gif" title="Worldometer"/></a></div> <button class="navbar-toggle" data-target="#navbar-main" data-toggle="collapse" type="button"> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span> </button> </div> <div class="navbar-collapse collapse" id="navbar-main"> <ul class="nav navbar-nav"> <li><a href="/coronavirus/"><span style="color:#FF9900; font-weight:bold">Coronavirus</span></a></li> <li><a href="/population/">Population</a></li> </ul> </div> </div></div><div class="container"><div class="row"><div style="text-align:left; margin-bottom:10px"><script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-slot="3287840995" style="display:inline-block;width:970px;height:90px"></ins><script> (adsbygoogle = window.adsbygoogle || []).push({});</script></div></div><div class="row"> <div class="col-md-2 hidden-sm hidden-xs col-wm-left-ad"> <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-slot="9468680730" style="display:inline-block;width:160px;height:600px"></ins><script>(adsbygoogle = window.adsbygoogle || []).push({});</script></div><div class="col-md-6"> <div class="content-home"><div class="linkunderline" style="padding:20px; margin-bottom:20px; margin-top:20px; font-size:16px"><a href="/coronavirus/"><strong>Coronavirus Updates</strong></a></div><div class="counterdiv"><div class="counter-title-top">World Population</div><div class="counter-group" id="c1"><div class="counter-heading inactive-header" data-parent="#c1" data-target="#current_population" data-toggle="collapse"> <span class="counter-number"><span class="rts-counter" rel="current_population">retrieving data...</span></span><span class="counter-item"><a href="/world-population/">Current World Population</a></span></div><div class="collapse counter-body-wrap" id="current_population"><div class="counter-body"> <strong>World Population: </strong> <ul> <li>has reached 7 billion on October 31, 2011.</li> <li>is projected to reach 8 billion in 2023, 9 billion in 2037, and 10 billion people in the year 2055.</li> <li>has doubled in 40 years from 1959 (3 billion) to 1999 (6 billion).</li> <li>is currently (2020) growing at a rate of around 1.05 % per year, adding 81 million people per year to the total.</li> <li>growth rate reached its peak in the late 1960s, when it was at 2.09%.</li> <li>growth rate is currently declining and is projected to continue to decline in the coming years (reaching below 0.50% by 2050, and 0.03% in 2100) . </li> <li>a tremendous change occurred with the industrial revolution: whereas it had taken all of human history up to the year 1800 for world population to reach 1 billion, the second billion was achieved in only 130 years (1930), the third billion in 30 years (1960), the fourth billion in 15 years (1974), the fifth billion in 13 years (1987), the sixth billion in 12 years (1999) and the seventh billion in 12 years (2011). During the 20th century alone, the population in the world has grown from 1.65 billion to 6 billion.</li> </ul> <p><strong>Sources for the world population counter:</strong></p> <ul> <li><a href="https://esa.un.org/unpd/wpp/" target="_blank">World Population Prospect: the 2019 Revision</a> - United Nations, Department of Economic and Social Affairs, Population Division (June 2019)</li> <li><a href="http://www.census.gov/population/international/" target="_blank">International Programs Center at the U.S. Census Bureau, Population Division</a></li> </ul> <p><strong>For more detailed information: </strong></p> <ul> <li><a hr ...
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
# _qevents.push({
# qacct:"p-Pd9JxUkvV0m7q"
# });</script><noscript><div style="display:none;"><img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-Pd9JxUkvV0m7q.gif" width="1"/></div></noscript></link></body></html>

# %%
soup.get_text()
# Out:
# '       Worldometer - real time world statistics                Coronavirus Population      Coronavirus UpdatesWorld Population retrieving data...Current World Population World Population:   has reached 7 billion on October 31, 2011. is projected to reach 8 billion in 2023, 9 billion in 2037, and 10 billion people in the year 2055. has doubled in 40 years from 1959 (3 billion) to 1999 (6 billion). is currently (2020) growing at a rate of around 1.05 % per year, adding 81 million people per year to the total. growth rate reached its peak in the late 1960s, when it was at 2.09%. growth rate is currently declining and is projected to continue to decline in the coming years (reaching below 0.50% by 2050, and 0.03% in 2100) .  a tremendous change occurred with the industrial revolution: whereas it had taken all of human history up to the year 1800 for world population to reach 1 billion, the second billion was achieved in only 130 years (1930), the third billion in 30 years (1960), the fourth billion in 15 years (1974), the fifth billion in 13 years (1987), the sixth billion in 12 years (1999) and the seventh billion in 12 years (2011). During the 20th century alone, the population in the world has grown from 1.65 billion to 6 billion.  Sources for the world population counter:  World Population Prospect: the 2019 Revision - United Nations, Department of Economic and Social Affairs, Population Division (June 2019) International Programs Center at the U.S. Census Bureau, Population Division  For more detailed information:   World Population (Worldometer)  trends & more >  retrieving data...Births this year  "this year" = from January 1 (00:00) up to now   retrieving data...Births today  "today" = from the beginning of the current day up to now    retrieving data...Deaths this year   retrieving data...Deaths today   retrieving data...Net population growth this year  "net population growth" = births minus deaths    retrieving data...Net population growth today  Government & Economics $ retrieving data...Public Healthcare expenditure today Quick facts:   Total global healthcare expenditure represent around 9% of world GDP Government portion of healthcare expenditure is around 60%  Sources and info:   World Health Statistics - World Health Organization (WHO) World Economic Outlook (WEO) - International Monetary Fund (IMF) World Development Indicators (WDI) - World Bank   $ retrieving data...Public Education expenditure today Quick facts:  Public spending on education in the world is around 5% of global GDP  Sources and info:    Human Development Report - United Nations Global Education Digest - Unesco Institute for Statistics (UIS) World Bank Public Expenditure Database - edstats - World Bank   more info >  $ retrieving data...Public Military expenditure today Sources and info:  SIPRI military expenditure data - SIPRI  more info >  retrieving data...Cars produced this year Sources and info:  Car Production Statistics - International Organization of Motor Vehicle Manufacturers (OICA) Global Auto Report [Pdf file]  - ScotiaBank Light Vehicle Production Forecasts - IHS  more info >  retrieving data...Bicycles produced this year Quick facts:  As recently as 1965, bicycle and car production volumes were essentially the same, at nearly 20 million each per year, but as of 2003 bike production had climbed to over 100 million per year compared with around 50 million cars produced that year.   Sources and info:   Elaboration of Worldwatch Institute data Bicycle Retailer and Industry News - Statistics  more info >  retrieving data...Computers produced this year Sources and info:  Worldwide PC Shipments - Gartner Worldwide Quarterly PC Tracker - IDC  more info > Society & Media retrieving data...New book titles published this year Sources and info:  Bowker Book Industry Statistics UNESCO Institute for Statistics (UIS) - (United Nations Educational, Scientific and Cultural Organization)   more info >  retrieving data...Newspapers circulated todaySou ...

# %%
soup.head
# Out:
# <head> <meta charset="utf-8"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=device-width, initial-scale=1" name="viewport"/> <title>Worldometer - real time world statistics</title><meta content="Live world statistics on population, government and economics, society and media, environment, food, water, energy and health. Interesting statistics with world population clock, forest loss this year, carbon dioxide co2 emission, world hunger data, energy consumed, and a lot more" name="description"/><meta content="Worldometer - real time world statistics" property="og:title"><meta content="website" property="og:type"><meta content="http://www.worldometers.info/" property="og:url"><meta content="http://www.worldometers.info/img/worldometers-fb.jpg" property="og:image"><meta content="Worldometer" property="og:site_name"/><meta content="1810087514" property="fb:admins"/><meta content="Live world statistics on population, government and economics, society and media, environment, food, water, energy and health." property="og:description"/><script type="application/ld+json">{ "@context" : "http://schema.org", "@type" : "Organization", "name" : "Worldometer", "url" : "http://www.worldometers.info", "logo": "http://www.worldometers.info/img/logo-schema.gif", "sameAs" : [ "https://www.facebook.com/Worldometers.info", "https://twitter.com/Worldometers", "https://plus.google.com/+worldometers"]
# }</script><link href="/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link href="/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/><link href="/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/favicon/manifest.json" rel="manifest"/><meta content="#ffffff" name="msapplication-TileColor"/><meta content="/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/><meta content="#ffffff" name="theme-color"/><meta content="http://www.worldometers.info/img/worldometers-fb.jpg" property="og:image"> <link href="/css/bootstrap.min.css" rel="stylesheet"/><link href="/wm16.css" rel="stylesheet"/> <!--[if lt IE 9]> <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script> <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script> <![endif]--><script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script><script type="text/javascript"> var rts_configuration =
# {
# RTS_key: 'worldometers',
# RTS_keylen: 2,
# format_defaults : {
# decimalSeparator: '.',
# thousandSeparator: ','
# }
# }</script><script src="https://www.realtimestatistics.net/rts/RTSp.js" type="text/javascript"></script><script src="/js/counters.js" type="text/javascript"></script><link href="/css/accordion16.css" media="screen" rel="stylesheet" type="text/css"/><script type="text/javascript">$(document).ready(function () { $('.collapse') .on('shown.bs.collapse', function() { $(this) .parent() .find(".inactive-header") .removeClass("inactive-header") .addClass("active-header"); }) .on('hidden.bs.collapse', function() { $(this) .parent() .find(".active-header") .removeClass("active-header") .addClass("inactive-header"); }); });</script><link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/> <script src="/js/bootstrap.min.js"></script> <script src="/js/ie10-viewport-bug-workaround.js"></script></meta></meta></meta></meta></meta></head>

# %%
soup.find_all('a')
# Out:
# [<a class="navbar-brand" href="/"><img border="0" src="/img/worldometers-logo.gif" title="Worldometer"/></a>,
#  <a href="/coronavirus/"><span style="color:#FF9900; font-weight:bold">Coronavirus</span></a>,
#  <a href="/population/">Population</a>,
#  <a href="/coronavirus/"><strong>Coronavirus Updates</strong></a>,
#  <a href="/world-population/">Current World Population</a>,
#  <a href="https://esa.un.org/unpd/wpp/" target="_blank">World Population Prospect: the 2019 Revision</a>,
#  <a href="http://www.census.gov/population/international/" target="_blank">International Programs Center at the U.S. Census Bureau, Population Division</a>,
#  <a href="/world-population/"><strong>World Population</strong></a>,
#  <a href="/world-population/">trends &amp; more &gt;</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.who.int/gho/publications/world_health_statistics/2017/en/" target="_blank">World Health Statistics</a>,
#  <a href="https://www.imf.org/external/ns/cs.aspx?id=28" target="_blank">World Economic Outlook (WEO)</a>,
#  <a href="http://data.worldbank.org/data-catalog/world-development-indicators" target="_blank">World Development Indicators (WDI)</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://hdr.undp.org/en/" target="_blank">Human Development Report</a>,
#  <a href="http://www.uis.unesco.org/Education/Pages/global-education-digest.aspx" target="_blank">Global Education Digest</a>,
#  <a href="http://web.worldbank.org/WBSITE/EXTERNAL/TOPICS/EXTEDUCATION/EXTDATASTATISTICS/EXTEDSTATS/0,,contentMDK:21878970%7EmenuPK:5313042%7EpagePK:64168445%7EpiPK:64168309%7EtheSitePK:3232764,00.html" target="_blank">World Bank Public Expenditure Database</a>,
#  <a href="/education/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.sipri.org/research/armaments/milex" target="_blank"> SIPRI military expenditure data</a>,
#  <a href="/military/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://oica.net/category/production-statistics/" target="_blank">Car Production Statistics</a>,
#  <a href="http://www.gbm.scotiabank.com/English/bns_econ/bns_auto.pdf" target="_blank">Global Auto Report [Pdf file] </a>,
#  <a href="http://www.ihs.com/products/automotive/light-vehicle-forecasts/light-vehicle-production.aspx">Light Vehicle Production Forecasts</a>,
#  <a href="/cars/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.worldwatch.org/node/5462" target="_blank">Worldwatch Institute</a>,
#  <a href="/bicycles/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="https://www.gartner.com/newsroom/id/3844572" target="_blank">Worldwide PC Shipments</a>,
#  <a href="http://www.gartner.com/technology/home.jsp">Gartner</a>,
#  <a href="http://www.idc.com/tracker/showproductinfo.jsp?prod_id=1" target="_blank">Worldwide Quarterly PC Tracker</a>,
#  <a href="http://www.idc.com/">IDC</a>,
#  <a href="/computers/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.bowker.com/en-US/">Bowker Book Industry Statistics</a>,
#  <a href="http://www.uis.unesco.org/Pages/default.aspx" target="_blank">UNESCO Institute for Statistics (UIS)</a>,
#  <a href="/books/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.wan-ifra.org/microsites/world-press-trends" target="_blank">World Press Trends</a>,
#  <a href="http://www.wan-ifra.org/">World Association of Newspapers and News Publishers</a>,
#  <a href="/newspapers/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.displaysearch.com/cps/rde/xchg/displaysearch/hs.xsl/reports_tvs.asp" target="_blank">Display Search</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.gartner.com/technology/home.jsp" target="_blank">Gartner</a>,
#  <a href="http://www.idc.com/prodserv/idc_telnet.jsp" target="_blank">IDC Telecom and Networks</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.gartner.com" target="_blank">Gartner</a>,
#  <a href="http://www.dfcint.com/" target="_blank">DFC Intelligence</a>,
#  <a href="http://www.npd.com/corpServlet?nextpage=entertainment-categories_s.html" target="_blank">NDP Group - Entertainment Market Research </a>,
#  <a href="http://data.worldbank.org/data-catalog/world-development-indicators" target="_blank">World Development Indicators (WDI)</a>,
#  <a href="http://www.itu.int/ITU-D/ict/publications/idi/" target="_blank">Measuring the Information Society</a>,
#  <a href="http://www.comscore.com/" target="_blank">comScore</a>,
#  <a href="http://www.gfk.com/" target="_blank">GfK group</a>,
#  <a href="http://www.internetlivestats.com/internet-users/" rel="nofollow">trends &amp; more &gt;</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.radicati.com/" target="_blank">The Radicati Group </a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://technorati.com/state-of-the-blogosphere/" target="_blank">Technorati on State of the Blogosphere</a>,
#  <a href="http://en.wordpress.com/stats/" target="_blank">WordPress Stats</a>,
#  <a href="/blogs/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.internetlivestats.com/twitter-statistics/" rel="nofollow">trends &amp; more &gt;</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.comscore.com/" target="_blank">comScore</a>,
#  <a href="http://www.google.com/about/company/" target="_blank">Google Inc.</a>,
#  <a href="http://www.internetlivestats.com/google-search-statistics/" rel="nofollow">trends &amp; more &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.fao.org/forestry/fra/en/" target="_blank">Global Forest Resources Assessment (2010)</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.fao.org/docrep/u8480e/U8480E0D.HTM" target="_blank">Dimensions of need: Restoring the land</a>,
#  <a href="/co2-emissions/">CO2 emissions</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="https://www.iea.org/statistics/" target="_blank">International Energy Agency (IEA) Statistics </a>,
#  <a href="http://cdiac.ornl.gov/" target="_blank">Carbon Dioxide Information Analysis Center (CDIAC)</a>,
#  <a href="http://www.eia.gov/" target="_blank">U.S. Energy Information Administration (EIA) </a>,
#  <a href="/co2-emissions/">trends &amp; more &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.unccd.int/" target="_blank">United Nations Convention to Combat Desertification</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.epa.gov/tri/">Toxic Release Inventory (TRI) Program</a>,
#  <a href="http://www.unep.org/" target="_blank">United Nations Environment Program</a>,
#  <a href="http://www.epa.gov/" target="_blank">U.S. Environmental Protection Agency</a>,
#  <a href="/view/toxchem/">more info &gt;</a>,
#  <a href="http://www.fao.org/publications/sofi/en/" target="_blank">The State of Food Insecurity in the World</a>,
#  <a href="/undernourishment/">more info &gt;</a>,
#  <a href="http://www.who.int/mediacentre/factsheets/fs311/en/" target="_blank">Obesity and overweight</a>,
#  <a href="/weight-loss/">more info &gt;</a>,
#  <a href="http://www.who.int/mediacentre/factsheets/fs311/en/" target="_blank">Obesity and overweight</a>,
#  <a href="/obesity/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.wfp.org/hunger/stats" target="_blank">Hunger Stats</a>,
#  <a href="http://www.who.int/whr/en/index.html" target="_blank">World Health Report</a>,
#  <a href="http://www.unicef.org/sowc/index.html" target="_blank">The State of the World's Children</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.unccd.int/" target="_blank">Featured Page </a>,
#  <a href="/obesity/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://content.healthaffairs.org/content/28/5/w822.short" target="_blank">Annual Medical Spending Attributable To Obesity</a>,
#  <a href="http://www.rti.org/" target="_blank">RTI International<br/> </a>,
#  <a href="http://www.ahrq.gov/" target="_blank">Agency for Healthcare Research and Quality</a>,
#  <a href="http://www.cdc.gov/" target="_blank">Centers for Disease Control and Prevention (CDC)</a>,
#  <a href="http://www.marketresearch.com/product/display.asp?productid=6314539" target="_blank">The U.S. Weight Loss &amp; Diet Control Market</a>,
#  <a href="http://www.americashealthrankings.org/" target="_blank">America's Health Rankings</a>,
#  <a href="/weight-loss/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.worldwatercouncil.org/en" target="_blank">World Water Council </a>,
#  <a href="/water/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/mediacentre/factsheets/fs391/en/" target="_blank">Drinking Water</a>,
#  <a href="http://www.who.int/topics/water/en/" target="_blank">Water</a>,
#  <a href="http://www.who.int/water_sanitation_health/publications/jmp-2017/en/" target="_blank">Progress on drinking water, sanitation and hygiene</a>,
#  <a href="http://www.who.int/topics/water/en/" target="_blank">Water</a>,
#  <a href="http://www.who.int/water_sanitation_health/diseases-risks/diseases/diseasefact/en/" target="_blank">Water-related diseases: information sheets</a>,
#  <a href="/water/access-to-safe-water/">more info &gt;</a>,
#  <a href="https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy/downloads.html" target="_blank">BP Statistical Review of World Energy</a>,
#  <a href="http://en.wikipedia.org/wiki/World_energy_consumption" target="_blank">World Energy Consumption</a>,
#  <a href="/energy/">more info &gt;</a>,
#  <a href="http://www.iea.org/stats/index.asp" target="_blank">International Energy Agency (IEA) Statistics </a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://books.google.com/books/about/Energy.html?id=lm1WAAAACAAJ" target="_blank">Energy: A beginner's guide</a>,
#  <a href="http://en.wikipedia.org/wiki/Solar_energy" target="_blank">Solar Energy</a>,
#  <a href="http://www.eia.gov/cfapps/ipdbproject/IEDIndex3.cfm?tid=5&amp;pid=57&amp;aid=6">World Proved Reserves of Oil and Natural Gas, Most Recent Estimates</a>,
#  <a href="/oil/">more info &gt;</a>,
#  <a href="http://www.eia.gov/cfapps/ipdbproject/IEDIndex3.cfm?tid=5&amp;pid=57&amp;aid=6">World Proved Reserves of Oil and Natural Gas, Most Recent Estimates</a>,
#  <a href="/oil/">more info &gt;</a>,
#  <a href="http://www.eia.gov/cfapps/ipdbproject/IEDIndex3.cfm?tid=5&amp;pid=57&amp;aid=6">World Proved Reserves of Oil and Natural Gas, Most Recent Estimates</a>,
#  <a href="http://www.eia.gov/cfapps/ipdbproject/IEDIndex3.cfm?tid=5&amp;pid=57&amp;aid=6">World Proved Reserves of Oil and Natural Gas, Most Recent Estimates</a>,
#  <a href="/gas/">more info &gt;</a>,
#  <a href="/coal/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/healthinfo/global_burden_disease/en/" target="_blank">Global Burden of Disease (GBD)</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="https://www.cdc.gov/media/releases/2017/p1213-flu-death-estimate.html">Seasonal flu death estimate increases worldwide</a>,
#  <a href="https://www.who.int/mediacentre/news/statements/2017/flu/en/">Up to 650 000 people die of respiratory diseases linked to seasonal flu each year</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.unicef.org/childsurvival/index_newsline.html">Young child survival and development</a>,
#  <a href="http://www.childinfo.org/mortality.html" target="_blank">Child Mortality</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/reproductivehealth/en/" target="_blank">Sexual and reproductive health</a>,
#  <a href="http://www.sogc.org/jogc/abstracts/full/200912_WomensHealth_1.pdf" target="_blank"> "Unsafe abortion: global and regional incidence, trends, consequences, and challenges" (Pdf)</a>,
#  <a href="/abortions/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/features/qa/12/en/index.html" target="_blank">Why do so many women still die in pregnancy or childbirth?</a>,
#  <a href="http://www.thelancet.com/journals/lancet/article/PIIS0140-6736%2810%2960518-1/fulltext#" target="_blank">Maternal mortality for 181 countries, 1980—2008: a systematic analysis of progress towards Millennium Development Goal 5</a>,
#  <a href="http://www.who.int/hiv/data/en/">HIV/AIDS Statistics</a>,
#  <a href="http://www.avert.org/worldstats.htm" target="_blank">Global HIV and AIDS estimates</a>,
#  <a href="/aids/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.unaids.org/en/dataanalysis/" target="_blank">UNAIDS</a>,
#  <a href="/aids/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/cancer/en/" target="_blank">Cancer</a>,
#  <a href="/cancer/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/features/factfiles/malaria/en/index.html" target="_blank">Malaria</a>,
#  <a class="settype" href="javascript:void(0)">today</a>,
#  <a href="http://www.who.int/tobacco/en/atlas8.pdf" target="_blank">Cigarette Consumption - Tobacco Atlas [Pdf] </a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/gho/tobacco/en/index.html" target="_blank">Tobacco Control, Global Health Observatory (GHO)</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/gho/alcohol/en/index.html" target="_blank">Global Information System on Alcohol and Health (GISAH)</a>,
#  <a href="/alcohol/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/mental_health/prevention/suicide/suicideprevent/en/index.html" target="_blank">Suicide prevention (SUPRE) </a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.pbs.org/wgbh/pages/frontline/shows/drugs/business/" target="_blank">The illegal drugs global business</a>,
#  <a href="/drugs/">more info &gt;</a>,
#  <a class="settype" href="javascript:void(0)">this year</a>,
#  <a href="http://www.who.int/mediacentre/events/meetings/2011/road_safety/en/index.html" target="_blank">Global launch of the Decade of Action for Road Safety 2011-2020</a>,
#  <a href="/"><img border="0" class="img-footer" src="/img/worldometers-logo-footer.png"/></a>,
#  <a href="/about/">about</a>,
#  <a href="/faq/">faq</a>,
#  <a href="/languages/">languages</a>,
#  <a href="/contact/">contact</a>,
#  <a data-placement="bottom" data-toggle="tooltip" href="/newsletter-subscribe/" title="Newsletter"><i class="fa fa-bullhorn fa-round"></i></a>,
#  <a href="https://twitter.com/Worldometers"><i class="fa fa-twitter fa-round"></i></a>,
#  <a href="https://www.facebook.com/Worldometers.info"><i class="fa fa-facebook fa-round"></i></a>,
#  <a href="/disclaimer/">Disclaimer &amp; Privacy Policy</a>]
